# %% [markdown]
# <a href="https://colab.research.google.com/github/Netthip/Study/blob/main/Speech2Text.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
"pip install pythaiasr==0.2"
# Out:
# 'pip install pythaiasr==0.2'

# %%
"from pythaiasr import asr "
# Out:
# 'from pythaiasr import asr '

# %%
import IPython.display as ipd
ipd.Audio('/content/sample_data/english.wav')
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
import matplotlib.pyplot as plt
import librosa.display

x, sr = librosa.load('/content/sample_data/english.wav')
plt.figure(figsize=(14, 5))
librosa.display.waveshow(x, sr=sr)

# %%
import speech_recognition as sr
s2t = sr.Recognizer()
with sr.AudioFile('/content/sample_data/english.wav') as source:
  sound2text = s2t.listen(source)
text = s2t.recognize_google(sound2text)
print(text)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_5187/1514860573.py in <cell line: 0>()
# ----> 1 import speech_recognition as sr
#       2 s2t = sr.Recognizer()
#       3 with sr.AudioFile('/content/sample_data/english.wav') as source:
#       4   sound2text = s2t.listen(source)
#       5 text = s2t.recognize_google(sound2text)
#
# ModuleNotFoundError: No module named 'speech_recognition'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
# !pip install SpeechRecognition
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 32.9/32.9 MB 37.8 MB/s eta 0:00:00
# ...

# %%
import IPython.display as ipd
import librosa

# Load the audio file and its sample rate using librosa
audio_data, sample_rate = librosa.load('/content/sample_data/english.wav')

# Play the audio using ipd.Audio, explicitly providing the data and sample rate
ipd.Audio(audio_data, rate=sample_rate)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
import matplotlib.pyplot as plt
import librosa.display

x, sr = librosa.load('/content/sample_data/english.wav')
plt.figure(figsize=(14, 5))
librosa.display.waveshow(x, sr=sr)
